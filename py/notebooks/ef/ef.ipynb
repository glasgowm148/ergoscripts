# %%
#!pip3 install wheel
#!pip3 install pandas

import pandas as pd
import requests
pd.set_option('display.float_format', lambda x: '%.3f' % x)
pd.options.display.max_rows = 999

from pandas import json_normalize
import json


#!pip3 install seaborn
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (20.0, 10.0)

# %%
url = 'https://api.ergoplatform.com/api/v1/addresses/4L1ktFSzm3SH1UioDuUf5hyaraHird4D2dEACwQ1qHGjSKtA6KaNvSzRCZXZGf9jkfNAEC1SrYaZmCuvb2BKiXk5zW9xuvrXFT7FdNe2KqbymiZvo5UQLAm5jQY8ZBRhTZ4AFtZa1UF5nd4aofwPiL7YkJuyiL5hDHMZL1ZnyL746tHmRYMjAhCgE7d698dRhkdSeVy/transactions'
r = requests.get(url)
json = r.json()
#total_record = int(json['total'])
#print("Total record: " +str(total_record))

df = pd.json_normalize(json['items'])
# drop unwanted columns 
df = df.drop(['inclusionHeight', 'numConfirmations', 'dataInputs', 'index', 'globalIndex', 'size'],axis =1)
df
# Out:
#                                                    id  \
# 0   9d4cc3eb6b20178f2c5a145184ec70702f31178d757639...
# 1   ee59dc0062727b1b1dd7a7e8ca72ba4857d1af3a86ee69...
# 2   f7d478cb33f217eb3ca64d9985063225e72f14fbfc5608...
# 3   c9ef65758ef4d23f751d9fc9aa8b70663d74a32317f36b...
# 4   4774d7e7bbb4a137c79be2947fdd8c5c209f7e9c652932...
# 5   46dde21b62f858362797a1e2afd15c953bfcf9e9abfe56...
# 6   bed6afe640b02acdaddcb66306a2be151f0bb12a4895fb...
# 7   2e02c2bd4dc0dc1ad0d5b0fb8f8772db8d8b440c29d4c7...
# 8   7b10b1f23c861c150e00b5f22f595241a1de14d669de4e...
# 9   8d079376548b9fdb978c93a6c21c4c005e73ea8f7e3397...
# 10  d8a17c5e66a82230e2743636b824a8f3e4c3289d041ea1...
# 11  0fe8a7a3e470add62930b027fcc64d33e92dfea69fd4ac...
# 12  1a239f838fc0c6785b04f857342bdd0bcd8c265f3ceeec...
# 13  d0187847ed12bbe2f799c1f1edb93dfaaec363de94cc80...
# 14  622056f5e4ff4d063af419739aa90e9ab7ca291fe2638f...
# 15  d4644083943a35fcbc2d1f98bb9600d9fe8bcff3defa4f...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         20 non-null     object
#  1   blockId    20 non-null     object
#  2   timestamp  20 non-null     int64
#  3   inputs     20 non-null     object
#  4   outputs    20 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 928.0+ bytes

# %%
# for investigating parsing errors 
df.to_csv("ef.csv", index=False)

df.head()
# Out:
#                                                   id  \
# 0  9d4cc3eb6b20178f2c5a145184ec70702f31178d757639...
# 1  ee59dc0062727b1b1dd7a7e8ca72ba4857d1af3a86ee69...
# 2  f7d478cb33f217eb3ca64d9985063225e72f14fbfc5608...
# 3  c9ef65758ef4d23f751d9fc9aa8b70663d74a32317f36b...
# 4  4774d7e7bbb4a137c79be2947fdd8c5c209f7e9c652932...
#
#                                              blockId      timestamp  \
# 0  78d7baf7728376c89936610e21b9ae81f78544ecfa6729...  1672152989355
# 1  9d41574055f029e5063fec1ced867ebb6f5e51bdfd8121...  1669833570103
# 2  42054ac009ad75fa2eb1cd776eb3e05edfbcbf58e5d88f...  1668499428809
# 3  2a216ae0e1253ad4895cee92539b368b67c09a7a2b7993...  1666775654147
# 4  d7aa56894d84ddf40a46c363a35140a4ed348dac0c80a7...  1662656365378
#
#                                               inputs  \
# 0  [{'boxId': 'eac962e346718035b0dc83707440feee98...
# 1  [{'boxId': '9bfc2d9b09b3093d0813e32e67946b667d...
# 2  [{'boxId': '600f852bed6f7957a413c12ed57471d2fb...
# ...
