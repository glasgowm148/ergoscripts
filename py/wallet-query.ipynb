# %% [markdown]
# # Instructions
#
# To start, go to Kernal -> 'Restart and Run All' -> 'Restart and Run All Cells'
#
# replace the wallet address in the cell below with the address you want to analyse

# %%
# Bearwhale wallet v2 : 9eyXNatnA6YM4tS1TjadEA6TFrd9bdufbFuykV89iX9vE9RBZZe
# v1 : 9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpaSk1d3
target = '9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpaSk1d3'

# %% [markdown]
# # Imports

# %%
#!pip install pandas
import pandas as pd
import requests
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %% [markdown]
# # Pull
#
# API Request to pull the data and then place it into a pandas dataframe. You can analyse the json directly by uncommenting these lines below.

# %%
# API Request
# Docs : https://api.ergoplatform.com/api/v1/docs/

import requests
for p in range(1,50):
    url = 'https://api.ergoplatform.com/api/v1/boxes/byAddress/9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpaSk1d3'+'?page='+str(p)
    r = requests.get(url)
    
    json = r.json()

# %%
# Query the json directly

#json.keys()
#json['items']
json['total']
#json
# Out:
# 1514

# %%
# load json into a dataframe
df = pd.DataFrame(json['items'])
df
# Out:
#                                                 boxId  \
# 0   e1ac2813cc85405b63bfa0d7e3bdd4657a0839fcd4af82...
# 1   e8d78b00092c09252bc81de0ef448df2d5be7cd488fbe1...
# 2   d96c4e3fd381c649522bf031469f195ee962516b8d7283...
# 3   dd15c363be8446bf9c90a70df1f920d57e1fb8e839aec7...
# 4   f57f3b0f202d932190986cf4136b5f9cdbb952ad434c32...
# 5   ccf6060e7581fe5688b526967de4e468a6badcca30a5b6...
# 6   4164001de9ea0a7bd8586af86e6df6b9ba0b235ff6b853...
# 7   811948e33971ecb6e7986a6f583be69527566674bdd9c8...
# 8   b9f9525b201fcff0166f0c8696d82c66cbc1f8e7c36be1...
# 9   bc2aa7a488e1531428842c739a694eb2b8fb5c79a8e2c0...
# 10  10412d8ddceecda22fe771e9fb4e2909ec458845420986...
# 11  6aa967989b885d2d2ce90b0dc5a63af04db6d5c4f4f15e...
# 12  e4af702e6b87b2f94b9d9d44a093a791a6257016837dbf...
# 13  7a6959cc7ddecf9afe1c78a5af7c2c1d6af1e0c9ab7e0f...
# 14  662103f86df1673c827b064d46f3780e81cc6dc1afffb0...
# 15  d0952283c674b05dd14a06d3c925bba3687db2eb7cd7e7...
# 16  26a571201f267b744fde9f3ed88db1902fae3b968ba0ca...
# 17  36f3b479620148d6394cfa1602f08818818db4b2d7bf15...
# 18  d69aeb84dbf28ac60de948937e45b43ed9ba3dce939a8f...
# 19  3f374264eeb9b3f21e4c7cf11647c9c08d2ecd1ac3b0f1...
#
#                                         transactionId  \
# 0   451cad4e3a5110b54ebf7d9cc1d4bfb0d3c37db9bea516...
# 1   453474a00a44890733a62316663d0dfe86972c6b70737f...
# 2   5f69af11165917b6952efd30a352165e69268ddce3582d...
# 3   84480d498706c26c4758e808ea0ebaf3de3c201cf9ec26...
# 4   3420fdac766897cbd1b7c4ad3c822ce791e5c8e736a1a4...
# 5   13a1de4fedff2465512b13ddf95482b80d1131ee6fc95b...
# 6   c532a0630b19ba89bcacd31b261fe2b436056bf017560d...
# 7   20b1edc692b31bec7f8e472196a564bac9cda3778a4097...
0008cd03c67a23ed4581f6b6371ac3a211a30633c112de...
#
#                                               address  \
# 0   9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 1   9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 2   9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 3   9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 4   9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 5   9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 6   9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 7   9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 8   9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 9   9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 10  9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 11  9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 12  9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 13  9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 14  9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 15  9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 16  9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 17  9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 18  9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 19  9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
#
#                                                assets  \
# 0   [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 1   [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 2   [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 3   [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 4   [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 5   [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 6   [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 7   [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 8   [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 9   [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 10  [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 11  [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 12  [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 13  [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 14  [{'tokenId': '003bd19d0187117f130b62e1bcab0939...
# 15  [{'tokenId': '003bd19d0187117f130b62e1bcab0939...
# 16  [{'tokenId': '003bd19d0187117f130b62e1bcab0939...
# 17  [{'tokenId': '003bd19d0187117f130b62e1bcab0939...
# 18  [{'tokenId': '003bd19d0187117f130b62e1bcab0939...
# 19  [{'tokenId': '003bd19d0187117f130b62e1bcab0939...
#
#                                   additionalRegisters  \
# 0   {'R4': {'serializedValue': '0586a740', 'sigmaT...
# 1   {'R4': {'serializedValue': '05a0a68c06', 'sigm...
# 2   {'R4': {'serializedValue': '05f0b225', 'sigmaT...
# 3   {'R4': {'serializedValue': '058a9e02', 'sigmaT...
# 4   {'R4': {'serializedValue': '05da8f44', 'sigmaT...
# 5   {'R4': {'serializedValue': '05928a08', 'sigmaT...
# 6   {'R4': {'serializedValue': '0582ac34', 'sigmaT...
# 7   {'R4': {'serializedValue': '05c6da02', 'sigmaT...
# 8   {'R4': {'serializedValue': '05be979b03', 'sigm...
# 9   {'R4': {'serializedValue': '05bed601', 'sigmaT...
# 10  {'R4': {'serializedValue': '058eddf102', 'sigm...
# 11  {'R4': {'serializedValue': '05923b', 'sigmaTyp...
# 12  {'R4': {'serializedValue': '05a6fbf802', 'sigm...
# 13  {'R4': {'serializedValue': '0594fc67', 'sigmaT...
# 14  {'R4': {'serializedValue': '05ace02c', 'sigmaT...
# 15  {'R4': {'serializedValue': '05fae4a701', 'sigm...
# 16  {'R4': {'serializedValue': '0580cf41', 'sigmaT...
# 17  {'R4': {'serializedValue': '05cf0f', 'sigmaTyp...
# 18  {'R4': {'serializedValue': '05cf0f', 'sigmaTyp...
# 19  {'R4': {'serializedValue': '05cf0f', 'sigmaTyp...
#
#                                    spentTransactionId  mainChain
# 0                                                None       True
# 1   451cad4e3a5110b54ebf7d9cc1d4bfb0d3c37db9bea516...       True
# 2   453474a00a44890733a62316663d0dfe86972c6b70737f...       True
# 3   5f69af11165917b6952efd30a352165e69268ddce3582d...       True
# 4   84480d498706c26c4758e808ea0ebaf3de3c201cf9ec26...       True
# 5   3420fdac766897cbd1b7c4ad3c822ce791e5c8e736a1a4...       True
# 6   13a1de4fedff2465512b13ddf95482b80d1131ee6fc95b...       True
# 7   c532a0630b19ba89bcacd31b261fe2b436056bf017560d...       True
# 8   20b1edc692b31bec7f8e472196a564bac9cda3778a4097...       True
# 9   157c10068b797a61b58bef97e73e4667f10af69b9d713a...       True
# 10  06fd58a97e3ed47f8fbc86c9cfa258e82e299ff109b7d6...       True
# 11  5bc16e15beffd482a24c03cd8ee8a9626078e46c956c42...       True
# 12  b64d4c3a18b77d3d414fb8f2bc81555c791e350bc3204e...       True
# 13  4f13f7c26b7d5ca36b33363a41841ccf22d2aab562ef34...       True
# 14  6f7b114aa299de7be770033fbb88b262f3aa80f9c51323...       True
# 15  fa55aca0d8c066b3ddc22a598941ce169ec42c68cfd3f8...       True
# 16  f63c83f23f945b9ca6ea486ba9feb7839e5e6e6c7919cb...       True
# 17  799dfe690f247e913253b28ce99b1c4f76ab2d892d77d4...       True
# 18  50b6e900aa0c0c663188905a25a1accb65dfee6269ca11...       True
# 19  f70d2b72010fd63ea5ef15e04689b4dd4a35a4151a183e...       True

# %% [markdown]
# # Dataframe
#
# Pandas allows us to view the information easier, we drop the columns we don't need to here to clear up clutter.

# %%
df.info()

# boxId
# transactionId - tx id displayed on explorer
# blockId
# value - unspent 
# index - ? 
# creationHeight - time
# ergoTree -  0008cd023c166f1ba9de6fdd5ed90a6f15e037b0a9247a...
# address - wallet address
# assets - tokens
# additionalRegisters - sigma? R4
# spentTxId
# mainChain - main-net - True

#df.sort_values(by=['BalanceChange (ERG)'])
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   boxId                20 non-null     object
#  1   transactionId        20 non-null     object
#  2   blockId              20 non-null     object
#  3   value                20 non-null     int64
#  4   index                20 non-null     int64
#  5   creationHeight       20 non-null     int64
#  6   ergoTree             20 non-null     object
#  7   address              20 non-null     object
#  8   assets               20 non-null     object
#  9   additionalRegisters  20 non-null     object
#  10  spentTransactionId   19 non-null     object
#  11  mainChain            20 non-null     bool
# dtypes: bool(1), int64(3), object(8)
# memory usage: 1.9+ KB
#                                                 boxId  \
# 0   e1ac2813cc85405b63bfa0d7e3bdd4657a0839fcd4af82...
# 1   e8d78b00092c09252bc81de0ef448df2d5be7cd488fbe1...
# 2   d96c4e3fd381c649522bf031469f195ee962516b8d7283...
# 3   dd15c363be8446bf9c90a70df1f920d57e1fb8e839aec7...
# 4   f57f3b0f202d932190986cf4136b5f9cdbb952ad434c32...
# 5   ccf6060e7581fe5688b526967de4e468a6badcca30a5b6...
# 6   4164001de9ea0a7bd8586af86e6df6b9ba0b235ff6b853...
# 7   811948e33971ecb6e7986a6f583be69527566674bdd9c8...
# 8   b9f9525b201fcff0166f0c8696d82c66cbc1f8e7c36be1...
# 9   bc2aa7a488e1531428842c739a694eb2b8fb5c79a8e2c0...
# 10  10412d8ddceecda22fe771e9fb4e2909ec458845420986...
# 11  6aa967989b885d2d2ce90b0dc5a63af04db6d5c4f4f15e...
# 12  e4af702e6b87b2f94b9d9d44a093a791a6257016837dbf...
# 13  7a6959cc7ddecf9afe1c78a5af7c2c1d6af1e0c9ab7e0f...
# 14  662103f86df1673c827b064d46f3780e81cc6dc1afffb0...
# 15  d0952283c674b05dd14a06d3c925bba3687db2eb7cd7e7...
# 16  26a571201f267b744fde9f3ed88db1902fae3b968ba0ca...
# 17  36f3b479620148d6394cfa1602f08818818db4b2d7bf15...
# 18  d69aeb84dbf28ac60de948937e45b43ed9ba3dce939a8f...
# 19  3f374264eeb9b3f21e4c7cf11647c9c08d2ecd1ac3b0f1...
#
#                                         transactionId  \
# 0   451cad4e3a5110b54ebf7d9cc1d4bfb0d3c37db9bea516...
# 1   453474a00a44890733a62316663d0dfe86972c6b70737f...
# 2   5f69af11165917b6952efd30a352165e69268ddce3582d...
# 3   84480d498706c26c4758e808ea0ebaf3de3c201cf9ec26...
# 4   3420fdac766897cbd1b7c4ad3c822ce791e5c8e736a1a4...
0008cd03c67a23ed4581f6b6371ac3a211a30633c112de...
# 7           469055  0008cd03c67a23ed4581f6b6371ac3a211a30633c112de...
# 8           469051  0008cd03c67a23ed4581f6b6371ac3a211a30633c112de...
# 9           468541  0008cd03c67a23ed4581f6b6371ac3a211a30633c112de...
# 10          468530  0008cd03c67a23ed4581f6b6371ac3a211a30633c112de...
# 11          468465  0008cd03c67a23ed4581f6b6371ac3a211a30633c112de...
# 12          468461  0008cd03c67a23ed4581f6b6371ac3a211a30633c112de...
# 13          468369  0008cd03c67a23ed4581f6b6371ac3a211a30633c112de...
# 14          467322  0008cd03c67a23ed4581f6b6371ac3a211a30633c112de...
# 15          467151  0008cd03c67a23ed4581f6b6371ac3a211a30633c112de...
# 16          467052  0008cd03c67a23ed4581f6b6371ac3a211a30633c112de...
# 17          466953  0008cd03c67a23ed4581f6b6371ac3a211a30633c112de...
# 18          466947  0008cd03c67a23ed4581f6b6371ac3a211a30633c112de...
# 19          466941  0008cd03c67a23ed4581f6b6371ac3a211a30633c112de...
#
#                                               address  \
# 0   9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 1   9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 2   9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 3   9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 4   9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 5   9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 6   9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 7   9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 8   9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 9   9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 10  9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 11  9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 12  9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 13  9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 14  9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 15  9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 16  9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 17  9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 18  9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
# 19  9hyDXH72HoNTiG2pvxFQwxAhWBU8CrbvwtJDtnYoa4jfpa...
#
#                                                assets  \
# 0   [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 1   [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 2   [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 3   [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 4   [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 5   [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 6   [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 7   [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 8   [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 9   [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 10  [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 11  [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 12  [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 13  [{'tokenId': '03faf2cb329f2e90d6d23b58d91bbb6c...
# 14  [{'tokenId': '003bd19d0187117f130b62e1bcab0939...
# 15  [{'tokenId': '003bd19d0187117f130b62e1bcab0939...
# 16  [{'tokenId': '003bd19d0187117f130b62e1bcab0939...
# 17  [{'tokenId': '003bd19d0187117f130b62e1bcab0939...
# 18  [{'tokenId': '003bd19d0187117f130b62e1bcab0939...
# 19  [{'tokenId': '003bd19d0187117f130b62e1bcab0939...
#
#                                   additionalRegisters  \
# 0   {'R4': {'serializedValue': '0586a740', 'sigmaT...
# 1   {'R4': {'serializedValue': '05a0a68c06', 'sigm...
# 2   {'R4': {'serializedValue': '05f0b225', 'sigmaT...
# 3   {'R4': {'serializedValue': '058a9e02', 'sigmaT...
# 4   {'R4': {'serializedValue': '05da8f44', 'sigmaT...
# 5   {'R4': {'serializedValue': '05928a08', 'sigmaT...
# 6   {'R4': {'serializedValue': '0582ac34', 'sigmaT...
# 7   {'R4': {'serializedValue': '05c6da02', 'sigmaT...
# 8   {'R4': {'serializedValue': '05be979b03', 'sigm...
# 9   {'R4': {'serializedValue': '05bed601', 'sigmaT...
# 10  {'R4': {'serializedValue': '058eddf102', 'sigm...
# 11  {'R4': {'serializedValue': '05923b', 'sigmaTyp...
# 12  {'R4': {'serializedValue': '05a6fbf802', 'sigm...
# 13  {'R4': {'serializedValue': '0594fc67', 'sigmaT...
# 14  {'R4': {'serializedValue': '05ace02c', 'sigmaT...
# 15  {'R4': {'serializedValue': '05fae4a701', 'sigm...
# 16  {'R4': {'serializedValue': '0580cf41', 'sigmaT...
# 17  {'R4': {'serializedValue': '05cf0f', 'sigmaTyp...
# 18  {'R4': {'serializedValue': '05cf0f', 'sigmaTyp...
# 19  {'R4': {'serializedValue': '05cf0f', 'sigmaTyp...
#
#                                    spentTransactionId  mainChain
# 0                                                None       True
# 1   451cad4e3a5110b54ebf7d9cc1d4bfb0d3c37db9bea516...       True
# 2   453474a00a44890733a62316663d0dfe86972c6b70737f...       True
# 3   5f69af11165917b6952efd30a352165e69268ddce3582d...       True
# 4   84480d498706c26c4758e808ea0ebaf3de3c201cf9ec26...       True
# 5   3420fdac766897cbd1b7c4ad3c822ce791e5c8e736a1a4...       True
# 6   13a1de4fedff2465512b13ddf95482b80d1131ee6fc95b...       True
# 7   c532a0630b19ba89bcacd31b261fe2b436056bf017560d...       True
# 8   20b1edc692b31bec7f8e472196a564bac9cda3778a4097...       True
# 9   157c10068b797a61b58bef97e73e4667f10af69b9d713a...       True
# 10  06fd58a97e3ed47f8fbc86c9cfa258e82e299ff109b7d6...       True
# 11  5bc16e15beffd482a24c03cd8ee8a9626078e46c956c42...       True
# 12  b64d4c3a18b77d3d414fb8f2bc81555c791e350bc3204e...       True
# 13  4f13f7c26b7d5ca36b33363a41841ccf22d2aab562ef34...       True
# 14  6f7b114aa299de7be770033fbb88b262f3aa80f9c51323...       True
# 15  fa55aca0d8c066b3ddc22a598941ce169ec42c68cfd3f8...       True
# 16  f63c83f23f945b9ca6ea486ba9feb7839e5e6e6c7919cb...       True
# 17  799dfe690f247e913253b28ce99b1c4f76ab2d892d77d4...       True
# 18  50b6e900aa0c0c663188905a25a1accb65dfee6269ca11...       True
# 19  f70d2b72010fd63ea5ef15e04689b4dd4a35a4151a183e...       True

# %%
# Drop unneeded columns
df.drop(columns=['mainChain','ergoTree','transactionId','boxId', 
                 'blockId','address','index',
                 'additionalRegisters','spentTransactionId'], inplace=True)

# %% [markdown]
# # Tidy
#
# The UTXO model tracks the total balance on each transaction in nanoErgs. Some small fixes to make it more readable.

# %%
# Finding difference
df['BalanceChange (ERG)'] = df.value.diff()
df['HeightChange (h)'] = df.creationHeight.diff()
# nanoErg -> Erg
df['value'] = df['value'] / 1000000000
df['BalanceChange (ERG)'] = df['BalanceChange (ERG)'] / 1000000000
# Track this from geneis block ?
df['HeightChange (h)'] = df['HeightChange (h)'] * 2
df['HeightChange (h)'] = df['HeightChange (h)'] / 60
# Reversing polarity
df['BalanceChange (ERG)'] = df['BalanceChange (ERG)'] * -1 
df['HeightChange (h)'] = df['HeightChange (h)'] * -1 
df['BalanceChange (ERG)'] = df['BalanceChange (ERG)'].shift(-1)
df['HeightChange (h)'] = df['HeightChange (h)'].shift(-1)

# %% [markdown]
# # Tokens

# %%
# Pulling SigmaUSD out asset tokens
df3 = df['assets'].apply(pd.Series)
df4 = df3[0].apply(pd.Series)
df4.drop(columns=['tokenId','index','decimals','type', 
                 ], inplace=True)

# Merging back into original frame and tidying
df = pd.concat([df, df4], axis=1)
df.drop(columns=['assets'], inplace=True)
df = df.rename(columns={'value': 'Final Balance', 'amount': 'Sigma', 'name': 'type'})

# %%
pd.set_option('display.max_rows', 30)
df.sort_values(by=['BalanceChange (ERG)'], ascending=False)
df
# Out:
#     Final Balance  creationHeight  BalanceChange (ERG)  HeightChange (h)  \
# 0           0.548          469889            -1360.320            18.967
# 1        1360.869          469320           -16520.733             4.400
# 2       17881.602          469188             -818.891             0.600
# 3       18700.493          469170              -49.026             0.133
# 4       18749.519          469166            -1494.031             2.467
# 5       20243.550          469092             -177.664             0.367
# 6       20421.214          469081            -1151.422             0.867
# 7       21572.636          469055              -59.700             0.133
# 8       21632.337          469051            -9065.400            17.000
# 9       30697.736          468541              -37.314             0.367
# 10      30735.050          468530            -8227.544             2.167
# 11      38962.594          468465              -10.478             0.133
# 12      38973.073          468461            -8548.179             3.067
# 13      47521.251          468369            -9643.046            34.900
# 14      57164.297          467322            -1081.736             5.700
# 15      58246.034          467151            -4064.677             3.300
# 16      62310.711          467052           -21555.648             3.300
# 17      83866.359          466953                1.307             0.200
# 18      83865.052          466947                1.307             0.200
# 19      83863.745          466941                  nan               nan
#
#         Sigma    type
# 0   128697731  SigUSD
# 1   128170944  SigUSD
# 2   121778736  SigUSD
# 3   121472376  SigUSD
# 4   121454067  SigUSD
# 5   120896006  SigUSD
# 6   120829821  SigUSD
# 7   120401020  SigUSD
# 8   120378841  SigUSD
# 9   117010426  SigUSD
# 10  116996699  SigUSD
# 11  113967892  SigUSD
# 12  113964107  SigUSD
# 13  110876024  SigUSD
# 14     381048  SigRSV
# 15     381048  SigRSV
# 16     381048  SigRSV
# 17     381048  SigRSV
# 18     382048  SigRSV
# 19     383048  SigRSV

# %%
df['BalanceChange (ERG)'].sum()
import numpy as np
df['Final Balance'].sum()
df['Sigma'] = df['Sigma'].replace(np.nan, 0)
df
# Out:
#     Final Balance  creationHeight  BalanceChange (ERG)  HeightChange (h)  \
# 0           0.548          469889            -1360.320            18.967
# 1        1360.869          469320           -16520.733             4.400
# 2       17881.602          469188             -818.891             0.600
# 3       18700.493          469170              -49.026             0.133
# 4       18749.519          469166            -1494.031             2.467
# 5       20243.550          469092             -177.664             0.367
# 6       20421.214          469081            -1151.422             0.867
# 7       21572.636          469055              -59.700             0.133
# 8       21632.337          469051            -9065.400            17.000
# 9       30697.736          468541              -37.314             0.367
# 10      30735.050          468530            -8227.544             2.167
# 11      38962.594          468465              -10.478             0.133
# 12      38973.073          468461            -8548.179             3.067
# 13      47521.251          468369            -9643.046            34.900
# 14      57164.297          467322            -1081.736             5.700
# 15      58246.034          467151            -4064.677             3.300
# 16      62310.711          467052           -21555.648             3.300
# 17      83866.359          466953                1.307             0.200
# 18      83865.052          466947                1.307             0.200
# 19      83863.745          466941                  nan               nan
#
#         Sigma    type
# 0   128697731  SigUSD
# 1   128170944  SigUSD
# 2   121778736  SigUSD
# 3   121472376  SigUSD
# 4   121454067  SigUSD
# 5   120896006  SigUSD
# 6   120829821  SigUSD
# 7   120401020  SigUSD
# 8   120378841  SigUSD
# 9   117010426  SigUSD
# 10  116996699  SigUSD
# 11  113967892  SigUSD
# 12  113964107  SigUSD
# 13  110876024  SigUSD
# 14     381048  SigRSV
# 15     381048  SigRSV
# 16     381048  SigRSV
# 17     381048  SigRSV
# 18     382048  SigRSV
# 19     383048  SigRSV

# %%
df['Sigma Minted'] = df['Sigma'].diff(periods=-1)
df
# Out:
#     Final Balance  creationHeight  BalanceChange (ERG)  HeightChange (h)  \
# 0           0.548          469889            -1360.320            18.967
# 1        1360.869          469320           -16520.733             4.400
# 2       17881.602          469188             -818.891             0.600
# 3       18700.493          469170              -49.026             0.133
# 4       18749.519          469166            -1494.031             2.467
# 5       20243.550          469092             -177.664             0.367
# 6       20421.214          469081            -1151.422             0.867
# 7       21572.636          469055              -59.700             0.133
# 8       21632.337          469051            -9065.400            17.000
# 9       30697.736          468541              -37.314             0.367
# 10      30735.050          468530            -8227.544             2.167
# 11      38962.594          468465              -10.478             0.133
# 12      38973.073          468461            -8548.179             3.067
# 13      47521.251          468369            -9643.046            34.900
# 14      57164.297          467322            -1081.736             5.700
# 15      58246.034          467151            -4064.677             3.300
# 16      62310.711          467052           -21555.648             3.300
# 17      83866.359          466953                1.307             0.200
# 18      83865.052          466947                1.307             0.200
# 19      83863.745          466941                  nan               nan
#
#         Sigma    type  Sigma Minted
# 0   128697731  SigUSD    526787.000
# 1   128170944  SigUSD   6392208.000
# 2   121778736  SigUSD    306360.000
# 3   121472376  SigUSD     18309.000
# 4   121454067  SigUSD    558061.000
# 5   120896006  SigUSD     66185.000
# 6   120829821  SigUSD    428801.000
# 7   120401020  SigUSD     22179.000
# 8   120378841  SigUSD   3368415.000
# 9   117010426  SigUSD     13727.000
# 10  116996699  SigUSD   3028807.000
# 11  113967892  SigUSD      3785.000
# 12  113964107  SigUSD   3088083.000
# 13  110876024  SigUSD 110494976.000
# 14     381048  SigRSV         0.000
# 15     381048  SigRSV         0.000
# 16     381048  SigRSV         0.000
# 17     381048  SigRSV     -1000.000
# 18     382048  SigRSV     -1000.000
# 19     383048  SigRSV           nan

# %%
df['Price Paid'] = df['Sigma Minted'] / (df['BalanceChange (ERG)'] * -1) 
df['Price Paid'] = df['Price Paid'] / 100
df
# Out:
#     Final Balance  creationHeight  BalanceChange (ERG)  HeightChange (h)  \
# 0           0.548          469889            -1360.320            18.967
# 1        1360.869          469320           -16520.733             4.400
# 2       17881.602          469188             -818.891             0.600
# 3       18700.493          469170              -49.026             0.133
# 4       18749.519          469166            -1494.031             2.467
# 5       20243.550          469092             -177.664             0.367
# 6       20421.214          469081            -1151.422             0.867
# 7       21572.636          469055              -59.700             0.133
# 8       21632.337          469051            -9065.400            17.000
# 9       30697.736          468541              -37.314             0.367
# 10      30735.050          468530            -8227.544             2.167
# 11      38962.594          468465              -10.478             0.133
# 12      38973.073          468461            -8548.179             3.067
# 13      47521.251          468369            -9643.046            34.900
# 14      57164.297          467322            -1081.736             5.700
# 15      58246.034          467151            -4064.677             3.300
# 16      62310.711          467052           -21555.648             3.300
# 17      83866.359          466953                1.307             0.200
# 18      83865.052          466947                1.307             0.200
# 19      83863.745          466941                  nan               nan
#
#         Sigma    type  Sigma Minted  Price Paid
# 0   128697731  SigUSD    526787.000       3.873
# 1   128170944  SigUSD   6392208.000       3.869
# 2   121778736  SigUSD    306360.000       3.741
# 3   121472376  SigUSD     18309.000       3.735
# 4   121454067  SigUSD    558061.000       3.735
# 5   120896006  SigUSD     66185.000       3.725
# 6   120829821  SigUSD    428801.000       3.724
# 7   120401020  SigUSD     22179.000       3.715
# 8   120378841  SigUSD   3368415.000       3.716
# 9   117010426  SigUSD     13727.000       3.679
# 10  116996699  SigUSD   3028807.000       3.681
# 11  113967892  SigUSD      3785.000       3.612
# 12  113964107  SigUSD   3088083.000       3.613
# 13  110876024  SigUSD 110494976.000     114.585
# 14     381048  SigRSV         0.000       0.000
# 15     381048  SigRSV         0.000       0.000
# 16     381048  SigRSV         0.000       0.000
# 17     381048  SigRSV     -1000.000       7.652
# 18     382048  SigRSV     -1000.000       7.652
# 19     383048  SigRSV           nan         nan
